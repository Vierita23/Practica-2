# %% [markdown]
# <img src="img/logoitqv1.jpg" alt="Instituto Superior Tecnológico Quito" width="500">
# <br>
#
# # Programa2.Estandarizacion
#
# ## Estandarización de datos con StandardScaler
# <br>
#
# <img src="img/python_logo.png" alt="Python" width="300">
# <br>
#
# *Jesús Viera* https://github.com/Vierita23/Practica-2

# %%
from sklearn import preprocessing
import numpy as np

# %%
# Carga de datos.
X_train = np.array([[ 1., -1.,  2.],
                    [ 2.,  0.,  0.],
                    [ 0.,  1., -1.]])

# %%
# Limpieza de datos: estandarización.
standardizer = preprocessing.StandardScaler()
# Estandarizamos los datos de entrenamiento
X_train_std = standardizer.fit_transform(X_train)
print(X_train_std)
# Out:
# [[ 0.         -1.22474487  1.33630621]
#  [ 1.22474487  0.         -0.26726124]
#  [-1.22474487  1.22474487 -1.06904497]]

# %%
X_train_2 = np.array([[ 1., -1.,  2.],
                      [ 2.,  0.,  0.],
                      [ 0.,  1., -1.]])

# %%
# Aplicamos los métodos "fit" y "transform" por separado
f = preprocessing.StandardScaler()
f = f.fit(X_train)
X_train_2_std = f.transform(X_train_2)
print(X_train_2_std)
# Out:
# [[ 0.         -1.22474487  1.33630621]
#  [ 1.22474487  0.         -0.26726124]
#  [-1.22474487  1.22474487 -1.06904497]]

# %% [markdown]
# ## Comprobar si las matrices estandarizadas son iguales
#
# Si `fit_transform` sobre `X_train` y `fit` + `transform` sobre `X_train_2` (con los mismos datos) dan el mismo resultado, la comparación debe ser `True`.

# %%
# Comprobar si las matrices estandarizadas son iguales
print(np.array_equiv(X_train_std, X_train_2_std))
# Out:
# True
